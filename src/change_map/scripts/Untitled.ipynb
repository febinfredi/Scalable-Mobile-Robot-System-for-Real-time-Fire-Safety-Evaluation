# %%
from detect_changes import ChangeDetector

# %%
detector = ChangeDetector() 
im1 = "/home/deveshdatwani/Downloads/image1.jpeg"
im2 = "/home/deveshdatwani/Downloads/image2.jpeg"

# %%
change_map = detector.find_PCAKmeans(im1, im2)
# Out:
# /usr/lib/python3/dist-packages/sklearn/decomposition/_pca.py:456: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var

# %%
from matplotlib import pyplot as plt

plt.imshow(change_map)
plt.show()
